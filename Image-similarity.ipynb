# %%
import tensorflow as tf
import tensorflow_hub as hub
import glob
import PIL
from IPython.display import Image

# %%
# This function:
# Loads the PNG image at the given path
# Decodes the PNG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
  return img

# %%
module_handle = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4" 
module = hub.load(module_handle)
# Extract image features of the target image
target_img_path = '/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/0384af17685e5bf0c089c874b33e3f54.jpg'
target_img = load_img(target_img_path)
target_img = module(target_img)
print("-----------------------------------------------------------------------------------------")
print("Extracing image features of the target image is done")

# Extract image features of the input image
i = 0
input_count = 0
input_imgs = []
for filename in glob.glob('/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/*.jpg'):
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)
    input_imgs.append([features, filename])
    input_count = input_count + 1
print("-----------------------------------------------------------------------------------------")
print("Extracting image features of the %d input images is done" %(input_count))
# Out:
# -----------------------------------------------------------------------------------------
# Extracing image features of the target image is done
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/d7fbf14ce2e449cbd2a1fe59b3934779_jpg.rf.a2c8cde5ae62cba8340936f99fb0293c.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/5bfe3fd50d866c99342f51180e2f8e6e_jpg.rf.b02bd9cf8e1ac8161415d35c33dc64e2.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/bf72e4710e89c062d5996e4a8be21365_jpg.rf.4dc631347db9e5c571cfdb9f1c371be9.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/b07d3231b4de1e370234bc12b5ada881_jpg.rf.c51a3ee7bc4dd6ef78193902206500ae.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/ee3907fed4c66c540faa2270c19e5a24_jpg.rf.e63e726c7670b10179ccca7f3731876b.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/7e0aff297c993797c8ca689b70a67eb6_jpg.rf.4962567abf8c9968daafcee6008e49f3.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/a8189eb7758787dfc66a47ee2b0811a6_jpg.rf.52ce653e0f2d7afeae07873bb53980fd.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/db7e5ee7a02496748bbce5dac74c0d24_jpg.rf.a2250b8916f52df522935f02b7b20e2c.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/1f50babcf1e9df08d8388eb9e7ca4330_jpg.rf.36396fe4429fa4a5b5af089d8d461b82.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/4e57bd10dd1c1aad5b5ce418fcb22d06_jpg.rf.53b6cf550773a00a687ede487a269b2d.jpg
# -----------------------------------------------------------------------------------------
# Image count                     
jpg
# -----------------------------------------------------------------------------------------
# Image count                     :94
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/456ace252e0e977fdb42ff77fe8e74d5.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :95
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/394c354a4dd55eb0b6547275746d2b2a.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :96
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/419e7fd10029ce82d8bd9d39bdb73c7d.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :97
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/39b925e30193a7b184f714943bb2c68d.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :98
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/407d41abb96124948b15ee50f2bff373.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :99
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/542b4918455ccb3f9067ed62f07c97ad.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :100
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/209b45a845103ace92fcf9c8ee2eed87.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :101
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/465aac06c0a23b296527cf53b6a30a3c.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :102
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/40bbccd9b4b30110c974b2f2957359f2.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :103
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/31cb5c8740ebc4bf1e0b52285ba7d036.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :104
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/9ef6d2819ebc2eddb120dc4d635d4246.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :105
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/9e0fca93b0b1586919ad38eb524fd92c.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :106
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/42ab7986b401b83677e9be1c4710fdae.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :107
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/31de316694e445cc372cc7b65d69bd92.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :108
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/99f7fe59daba4c49a801c5f3598a1d79.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :109
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/390c01498127d9ac4a7e2ff0411ca0e1.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :110
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/61a7a36f61e4dde77710d47d0431ed57.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :111
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/197bacb0f5ea4adf33437e19b7064855.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :112
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/64c9e6ac7bf54d954cffc4612351ed3a.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :113
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/20d4caa8ad32318c116aae8276465f43.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :114
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/86af4ec1c3fbdad2af2f9d991e3e7677.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :115
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/85d23825ef669dc68a8425f5f80df3ea.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :116
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/075c8dc70047e21400e89251932814b1.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :117
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/72e9c8cd0594950a061e4e94ae87fcd8.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :118
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/46c5ac29832828634600675ddadc4ccf.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :119
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/397acefedfc936ad5c354c5372ce0e13.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :120
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/29fe3ad7a7f69e3ecae1fc674989957a.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :121
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/71e607a1eb0880080fc38337504d0db7.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :122
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/58d1da7b58a35477e04aaf6318d1e828.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :123
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/66c7fdd80ff068c16f99fc44ba335166.jpg
# -----------------------------------------------------------------------------------------
# Image count                     :124
# Image in process is             :/content/drive/My Drive/Colab Notebooks/diet-detector/test/test/78e70c54e9eaeac4547b4682c1cd3758.jpg
# -----------------------------------------------------------------------------------------
# Extracting image features of the 124 input images is done

# %%
# display target_img
print("Target Image\n")
im = PIL.Image.open(target_img_path)
im = im.resize((224,224))
display(im)

# Calculate Cosine similarity between target_img and input_imgs
similarities = []
for i in range(0,input_count):
  similarity = tf.keras.losses.cosine_similarity(target_img, input_imgs[i][0])
  similarities.append([similarity,input_imgs[i][1]])

# display top 3 input_imgs which are the most similar with the target_img
similarities.sort()
print("\n\nThe 3 most similr images \n")
for s in range(1,4):
  im = PIL.Image.open(similarities[s][1])
  im = im.resize((224,224))
  display(im)
  print("Similarity: %.3f\n" %similarities[s][0])
# Out:
# Target Image
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFCB31F8AC8>
# The 3 most similr images
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFCB31F8AC8>
# Similarity: -0.952
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFCB31F8AC8>
# Similarity: -0.950
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFCB31F8AC8>
# Similarity: -0.944
